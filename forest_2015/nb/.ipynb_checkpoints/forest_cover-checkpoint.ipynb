# %% [markdown]
# This is my very first Kaggle competition! I'm excited and I picked a pretty basic one - **categorize forest cover type** based on ~50 features. Looks like a job for a decision tree. I've never used one before, so I'll be learning here!

# %%
import pandas as pd
from sklearn import tree
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The training data is ~5MB so I can easily load it into memory. Yay!

# %%
df = pd.read_csv("../data/train.csv").drop('Id', axis=1)

# %%
print df.shape
# Out:
# (15120, 55)

# %%
print df.dropna().shape
# Out:
# (15120, 55)

# %% [markdown]
# No NaNs at all!? Thanks forest service!
#
# I'm going to run this right out of the box, per SKLearn's excellent documentation.

# %%
clf = tree.DecisionTreeClassifier()
Y = df['Cover_Type']
X = df.drop('Cover_Type', axis=1)
clf.fit(X,Y)
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best')

# %%
print df[df['Cover_Type'] == 1].shape
# Out:
# (2160, 55)

# %% [markdown]
# Cool, it ran the decision tree. But I have no idea what the decision surface looks like. I don't even know what the important features are. Let's take a look at a Principal Component Analysis on the data:

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
xy = dict()
for i in range(1,8):
    temp = df[df['Cover_Type'] == i].drop('Cover_Type', axis=1)
    xy[str(i)] = pca.fit(temp).transform(temp)


l = {'1':'white', '2':'green', '3':'black', '4':'red', '5':'violet', '6':'orange', '7':'yellow'}

fig = plt.figure(figsize=(8,4))
for i in xy:
    plt.scatter(xy[i][0], xy[i][1], label='test', c=l[i], s=100)

plt.title('Initial PCA of forest data')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %% [markdown]
# This looks very clustered and, if we were drawing a decision boundary in the PC space, it would be very difficult to get decent separation between some of the categories. But of course I haven't done any cross-validation, so I'm going to do that now.
#
# I will iterate through a range of k-fold cross validations and see which one allows my current decision tree to best fit the cross-validation data. This will take a while to run.

# %%
import time
def optimize_k(folds, model, _x_, _y_):
    scores = []
    std = []
    index = []
    start = time.clock()
    for i in range(2, folds):
        kf = KFold(len(_y_), n_folds = i, shuffle=True)
        _scores = []
        for train_index, test_index in kf:
            x_train, x_test = _x_[train_index], _x_[test_index]
            y_train, y_test = _y_[train_index], _y_[test_index]
            clf = model
            clf.fit(x_train, y_train)
            ypred = clf.predict(x_test)
            #_scores.append(accuracy_score(y_test, ypred))
            _scores.append( (ypred != y_test).mean())
        scores.append(np.mean(np.array(_scores)))
        #std.append(np.std(np.array(_scores)))
        index.append(i)
    #plt.errorbar(index, scores, std, marker='^')
    plt.plot(index, scores)
    plt.ylabel('Error rate')
    plt.xlabel('Folds')
    print 'Executed in ' + str(time.clock()-start) + 's'
    plt.show()
    
def test_model(folds, model, _x_, _y_, sub):
    start = time.clock()
    df_test = pd.read_csv("../../../../../WorkLocal/Kaggle/forest_2015/test.csv")
    test_X = df_test.drop('Id', axis=1)
    indices = df_test['Id']
    ypred = []

    kf = KFold(len(_y_), n_folds = folds, shuffle=True)
    _scores = []
    for train_index, test_index in kf:
        x_train, x_test = kx[train_index], kx[test_index]
        y_train, y_test = ky[train_index], ky[test_index]
        clf = model
        clf.fit(x_train, y_train)
        ypred.append(clf.predict(test_X))
    
    Ypred = np.array(ypred).mean(0)
    Ypred = np.around(Ypred)
    Ypred = Ypred.astype(int)
    export = pd.Series(Ypred, name='Cover_Type', index=indices)
    export.index.name = 'Id'
    export.to_csv('../../../../../WorkLocal/Kaggle/forest_2015/submission_1.csv', header=True, index=True)
    print "Prediction written to 'submission_"+str(sub)+".csv'"
    print 'Executed in ' + str(time.clock()-start) + 's'

# %%
from sklearn.cross_validation import KFold
from sklearn.metrics import accuracy_score
import time
kx = np.array(X)
ky = np.array(Y)

# %%
optimize_k(20, tree.DecisionTreeClassifier(), kx, ky)
# Out:
# Executed in 36.203902s

# %% [markdown]
# It looks like after about 12 folds in the training data, cross-validation performance starts to level off. That's good because more folds means more computing time. Unfortunately, this is only at about 80% description of the variance, which is not good enough, since the current leader has a 100% fit.
#
# Since this is my first competition, I will take this model and submit it to see what happens. I don't expect to get very far on the leader board, but it would be personal validation to not be the worst submission.
#
# The test data is much larger (~76MB) than the training data, but still small enough to fit into memory. I expect this will take a while, but I'll give it a shot anyway.

# %%
test_model(12, tree.DecisionTreeClassifier(), kx, ky, 1)
# Out:
# Prediction written to 'submission_1.csv'
# Executed in 11.367669s

# %% [markdown]
# Sweet! I am currently the **1106th best entry** (out of 1341). That's not so great, but hey it's my first one. My model only explained **60%** of the variation, so let's see what more I can do beyond using a default decision tree/k-fold CV methodology.
#
# Let's try a random forest with the default 10 classifiers

# %%
from sklearn.ensemble import RandomForestClassifier
optimize_k(20, RandomForestClassifier(), kx, ky)
# Out:
# Executed in 47.104288s

# %% [markdown]
# This is much faster and looks to be a slightly better method with K again being optimized around 12 (with asymptotically better prediction coming at higher K).
#
# Let's try optimizing the number of classifiers in the random forest:

# %%
scores = []
std = []
index = []
start = time.clock()
for i in range(2,30):
    kf = KFold(len(df), n_folds = 12, shuffle=True)
    _scores = []
    for train_index, test_index in kf:
        x_train, x_test = kx[train_index], kx[test_index]
        y_train, y_test = ky[train_index], ky[test_index]
        clf = RandomForestClassifier(n_estimators=i)
        clf.fit(x_train, y_train)
        ypred = clf.predict(x_test)
        #_scores.append(accuracy_score(y_test, ypred))
        _scores.append( (ypred != y_test).mean())
    scores.append(np.mean(np.array(_scores)))
    #std.append(np.std(np.array(_scores)))
    index.append(i)
plt.plot(index, scores)
plt.title('Error rate vs number of random forest classifiers')
print 'Executed in ' + str(time.clock()-start) + 's'
plt.show()
# Out:
# Executed in 130.969434s

# %% [markdown]
# This is again asymptotic, but I'd say 18 looks like a good number of classifiers. Let's try running the test set against this model.

# %%
test_model(12, RandomForestClassifier(n_estimators=18), kx, ky, 2)
# Out:
# Prediction written to 'submission_2.csv'
# Executed in 38.539377s

# %%
Ypred = np.array(ypred).mean(0)
Ypred = np.around(Ypred)
Ypred = Ypred.astype(int)
export = pd.Series(Ypred, name='Cover_Type', index=indices)
export.index.name = 'Id'
export.to_csv('../../../../../WorkLocal/Kaggle/forest_2015/submission_2.csv', header=True, index=True)

# %% [markdown]
# My score bumped up to **0.695** and I am now ranked **992 out of 1361**. Still not great, but I'm getting better!

# %% [markdown]
# Let's try nearest neighbors methodology:

# %%
from sklearn.neighbors import KNeighborsClassifier

optimize_k(20, KNeighborsClassifier(), kx, ky)
# Out:
# Executed in 21.976121s

# %%
scores = []
std = []
index = []
start = time.clock()
for i in range(1,8):
    kf = KFold(len(df), n_folds = 14, shuffle=True)
    _scores = []
    for train_index, test_index in kf:
        x_train, x_test = kx[train_index], kx[test_index]
        y_train, y_test = ky[train_index], ky[test_index]
        clf = KNeighborsClassifier(n_neighbors=i)
        clf.fit(x_train, y_train)
        ypred = clf.predict(x_test)
        #_scores.append(accuracy_score(y_test, ypred))
        _scores.append( (ypred != y_test).mean())
    scores.append(np.mean(np.array(_scores)))
    #std.append(np.std(np.array(_scores)))
    index.append(i)
plt.plot(index, scores)
plt.title('Error rate vs number of random forest classifiers')
print 'Executed in ' + str(time.clock()-start) + 's'
plt.show()
# Out:
# Executed in 9.869034s

# %% [markdown]
# Since this is lowest at neighbors=1, I don't expect this is a better model than the random forest. I'll avoid submitting this one.

# %% [markdown]
# Now let's try a one-vs-rest classifier with a SVC using a linear kernel:

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

optimize_k(10, OneVsRestClassifier(LinearSVC()), kx, ky)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-517d8807eaa0> in <module>()
#       2 from sklearn.svm import LinearSVC
#       3
# ----> 4 optimize_k(10, OneVsRestClassifier(LinearSVC()), kx, ky)
#
# <ipython-input-42-37bae7414c70> in optimize_k(folds, model, _x_, _y_)
#      12             y_train, y_test = _y_[train_index], _y_[test_index]
#      13             clf = model
# ---> 14             clf.fit(x_train, y_train)
#      15             ypred = clf.predict(x_test)
#      16             #_scores.append(accuracy_score(y_test, ypred))
#
# /usr/local/lib/python2.7/site-packages/sklearn/multiclass.pyc in fit(self, X, y)
#     200         """
#     201         self.estimators_, self.label_binarizer_ = fit_ovr(self.estimator, X, y,
# --> 202                                                           n_jobs=self.n_jobs)
#     203         return self
#     204
#
# /usr/local/lib/python2.7/site-packages/sklearn/multiclass.pyc in fit_ovr(estimator, X, y, n_jobs)
#      90     estimators = Parallel(n_jobs=n_jobs)(
#      91         delayed(_fit_binary)(estimator, X, Y[:, i], classes=["not %s" % i, i])
# ---> 92         for i in range(Y.shape[1]))
#      93     return estimators, lb
#      94
#
# /usr/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     651             self._iterating = True
#     652             for function, args, kwargs in iterable:
# --> 653                 self.dispatch(function, args, kwargs)
#     654
#     655             if pre_dispatch == "all" or n_jobs == 1:
#
# /usr/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     398         """
#     399         if self._pool is None:
# --> 400             job = ImmediateApply(func, args, kwargs)
#     401             index = len(self._jobs)
#     402             if not _verbosity_filter(index, self.verbose):
#
# /usr/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     136         # Don't delay the application, to avoid keeping the input
#     137         # arguments in memory
# --> 138         self.results = func(*args, **kwargs)
#     139
#     140     def get(self):
#
# /usr/local/lib/python2.7/site-packages/sklearn/multiclass.pyc in _fit_binary(estimator, X, y, classes)
#      59     else:
#      60         estimator = clone(estimator)
# ---> 61         estimator.fit(X, y)
#      62     return estimator
#      63
#
# /usr/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     701                                               self.C,
#     702                                               self.class_weight_,
# --> 703                                               rnd.randint(np.iinfo('i').max))
#     704         # Regarding rnd.randint(..) in the above signature:
#     705         # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:
