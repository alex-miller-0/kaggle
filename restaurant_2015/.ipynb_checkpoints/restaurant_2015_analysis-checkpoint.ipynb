# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Predicting Restaurant Revenue
# This is my second Kaggle competition. The goal is to predict a restaurant's revenue based on a number of factors. This competition has some money riding on it ($10,000) so it will be pretty competitive. Let's see how I do.

# %%
df = pd.read_csv('../../../../WorkLocal/Kaggle/restaurant_2015_data/train.csv')

# %% [markdown]
# There are a few dozen columns (P1-P37) containing obfuscated data. These don't appear to be dummy coded. I'm going to leave these alone for now and take a look at the opening data, city size, restaurant type, and city.
#
# ###Open date
# I will take the earliest date that a restaurant opened and look at revenues of restaurants as a function of the duration of time since that first date.

# %%
import datetime
dates = []
new_dates = []
for i in df['Open Date']:
    d=i.split('/')
    dates.append(datetime.datetime(int(d[2]), int(d[0]), int(d[1])))

#min_date = min(dates)
min_date = datetime.datetime.today()
for j in dates:
    new_dates.append((j - min_date).total_seconds())

df['Open Date'] = (np.array(new_dates)/ max(new_dates))

# %%
df.plot(kind='scatter', x='Open Date', y='revenue')
plt.show()

# %% [markdown]
# ###City group:
# City group is a binary variable: it is either a big city or other.

# %%
df.boxplot(column='revenue', by='City Group')

# %% [markdown]
# ###Restaurant type:

# %%
df.boxplot(column='revenue', by='Type')

# %% [markdown]
# ###City:

# %%
df.boxplot(column='revenue', by='City')

# %% [markdown]
# I'm not seeing a whole lot to go on with these features. Maybe I will just start off with a regularized regression and see what happens.

# %% [markdown]
# ##Shotgun approach:

# %%
def dummies(df):  
    df = df.drop('Id', axis=1)

    cg = pd.get_dummies(df['City Group'], prefix='city_group')
    df = df.drop(['City Group'], axis=1)
    df = pd.concat([df, cg], axis=1)
    
    #These two features have additional values in the test set that don't appear in
    # the training set. I will just drop them.
    df = df.drop(['Type'], axis=1)
    df = df.drop(['City'], axis=1)


    dates = []
    new_dates = []
    for i in df['Open Date']:
        d=i.split('/')
        dates.append(datetime.datetime(int(d[2]), int(d[0]), int(d[1])))
    today_date = datetime.datetime.today()
    for j in dates:
        new_dates.append((today_date - j).total_seconds())
    #df['Open Date'] = (np.array(new_dates)/ max(new_dates))
    df['Open Date'] = np.array(new_dates)
    
    
    
    #for i in range(1,38):
    #    for k in range(1,38):
    #        if i!=k:
    #            df['P_'+str(i)+str(k)] = df['P'+str(i)]*df['P'+str(k)]
    return df

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
import time
from sklearn import cross_validation

def optimize_k(folds, model, _x_, _y_):
    scores = []
    std = []
    index = []
    start = time.clock()
    for i in range(1, folds):
        #kf = KFold(len(_y_), n_folds = i, shuffle=True)
        kf = cross_validation.LeavePOut(len(_y_), p=i)
        _scores = []
        for train_index, test_index in kf:
            x_train, x_test = _x_[train_index], _x_[test_index]
            y_train, y_test = _y_[train_index], _y_[test_index]
            clf = model
            clf.fit(x_train, y_train)
            y_pred = clf.predict(x_test)
            _scores.append(mean_squared_error(y_test, y_pred))
        scores.append(np.mean(np.array(_scores)))
        index.append(i)
    plt.plot(index, scores)
    plt.ylabel('Mean squared error')
    plt.xlabel('p in leave-p-out')
    print 'Executed in ' + str(time.clock()-start) + 's'
    plt.show()

def optimize_order(iterations, k, _x_, _y_):
    scores_low = []
    order_low = []
    scores = []
    order = []

    start = time.clock()

    for i in range(1, 5):
        temp_scores = []
        for cycle in range(iterations):
            cycle_scores = []
            lko = KFold(len(_y_), n_folds=k, shuffle=True)
            for train_index, test_index in lko:
                x_train, x_test = _x_[train_index], _x_[test_index]
                y_train, y_test = _y_[train_index], _y_[test_index]
                model = make_pipeline(PolynomialFeatures(i), Ridge()).fit(x_train, y_train)
                y_pred = model.predict(x_test)
                cycle_scores.append(mean_squared_error(y_test, y_pred))
            temp_scores.append(np.array(cycle_scores).mean())
        if i < 6:
            scores_low.append(np.array(temp_scores).mean())
            order_low.append(i)
        scores.append(np.array(temp_scores).mean())
        order.append(i)

    fig = plt.figure(figsize=(14, 4))

    plt.subplot(121)
    plt.title('LKO score vs order')
    plt.xlabel('Order')
    plt.ylabel('Score')
    plt.plot(order, scores)

    plt.subplot(122)
    plt.title('LKO score vs lower orders')
    plt.xlabel('Order')
    plt.ylabel('Score')
    plt.plot(order_low, scores_low, color='red')

    plt.show()
    print 'Polynomial order optimization executed in: ' + str(time.clock() - start) + 's'
    
def test_model(folds, model, _x_, _y_, sub):
    #Home
    path = "../../../../WorkLocal/Kaggle/restaurant_2015_data/"
    #Work
    #path = "../../../../../WorkLocal/Kaggle/kaggle/forest_2015/data/"
    start = time.clock()
    df_test = pd.read_csv(path + "test.csv")
    indices = df_test['Id']
    
    df_test = dummies(df_test)
    
    ypred = []
    
    kf = cross_validation.LeavePOut(len(_y_), p=folds)
    #kf = KFold(len(_y_), n_folds = folds, shuffle=True)
    _scores = []
    for train_index, test_index in kf:
        x_train, x_test = _x_[train_index], _x_[test_index]
        y_train, y_test = _y_[train_index], _y_[test_index]
        clf = model
        clf.fit(x_train, y_train)
        ypred.append(np.exp(clf.predict(np.array(df_test))))
    
    Ypred = np.array(ypred).mean(0)
    export = pd.Series(Ypred, name='Prediction', index=indices)
    export.index.name = 'Id'
    export.to_csv(path + 'submission_'+str(sub)+'.csv', header=True, index=True)
    print "Prediction written to 'submission_"+str(sub)+".csv'"
    print 'Executed in ' + str(time.clock()-start) + 's'

# %%
from sklearn.cross_validation import KFold
from sklearn.metrics import accuracy_score

dff_master = pd.read_csv('../../../../WorkLocal/Kaggle/restaurant_2015_data/train.csv')
dff = dummies(dff_master)

X = np.array(dff.drop('revenue', axis=1))
y = np.array(dff['revenue'])

# %%
optimize_k(3, Ridge(), X,y)
# Out:
# Executed in 4.740775s

# %% [markdown]
# The computing time blows up for p>2 in leave-p-out CV, but it looks like just leaving 1 out is the way to go.

# %%
#test_model(4, Ridge(), X, y, 1)

# %% [markdown]
# This didn't work very well. There is a serious overfitting problem here. Type and city both have a number of values in the test set that don't appear in the training set, so I can't use those. I have no idea what the Px variables are, but let's look at histograms.

# %%
dff.ix[:,0:38].hist(figsize=(14,14),bins=40)
plt.show()

# %% [markdown]
# None of these features is binomial, so they can all be fit with a regression. However, I have so far only been using a linear regression. I'll switch that to a polynomial one and see how it goes.
#
# ###Polynomial model:

# %%
#optimize_order(10, 2, X, y)
# Out:
# Polynomial order optimization executed in: 481.424783s

# %% [markdown]
# A polynomial model doesn't seem to help and it takes forever. Let's try a pure linear model without regularization.
#
# ###Pure linear model:

# %%
from sklearn.linear_model import LinearRegression

optimize_k(3, LinearRegression(), X,y)
# Out:
# Executed in 11.533273s

# %%
test_model(1, LinearRegression(), X, y, 1)
# Out:
# Prediction written to 'submission_1.csv'
# Executed in 6.73094s

# %% [markdown]
# The linear model didn't help.
#
# It was suggested in the forum to use log(revenue) because it is skewed. This is probably a good idea anyway because the range is very large (since these are large numbers relative to everything else). I have changed the evaluation of the test set to transform ln(y) back to y.
#
# ###Using ln(revenue)

# %%
y = np.log(y)

# %%
optimize_k(3, LinearRegression(), X,y)
# Out:
# Executed in 10.958943s

# %%
optimize_k(3, Ridge(), X,y)
# Out:
# Executed in 4.593778s

# %% [markdown]
# The log transform didn't help. Since there is a big overfitting problem, I should take a look at optimizing the alpha parameter in the regularization procedure. It should be increased to increase the penalty of poorly fitting features.
#
# ###Optimizing alpha:

# %%
def optimize_alpha(_x_,_y_):
    scores = []
    std = []
    index = []
    start = time.clock()
    for i in range(1,100):
        _scores = []
        kf = cross_validation.LeavePOut(len(_y_), p=1)
        for train_index, test_index in kf:
            x_train, x_test = _x_[train_index], _x_[test_index]
            y_train, y_test = _y_[train_index], _y_[test_index]
            #a = 0.1*i
            a = i
            clf = Ridge(alpha=a)
            clf.fit(x_train, y_train)
            y_pred = clf.predict(x_test)
            _scores.append(mean_squared_error(y_test, y_pred))
        scores.append(np.mean(np.array(_scores)))
        index.append(a)
    plt.plot(index, scores)
    plt.ylabel('Mean squared error')
    plt.xlabel('alpha')
    print 'Executed in ' + str(time.clock()-start) + 's'
    plt.show()

# %%
optimize_alpha(X,y)
# Out:
# Executed in 6.553276s

# %% [markdown]
# Alpha of 40 or so looks good. We are increasing the penalty on poorly fitting features. Since there is a big overfitting problem here, I suspect this will increase my score.

# %%
test_model(1, Ridge(alpha=40), X, y, 1)
# Out:
# Prediction written to 'submission_1.csv'
# Executed in 7.168053s

# %%
dff2 = dummies(dff_master)
dff2['Open Date'].max()
# Out:
# 596628389.17051399
